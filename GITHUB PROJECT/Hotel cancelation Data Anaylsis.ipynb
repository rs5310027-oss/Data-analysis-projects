# %% [markdown]
# Hotel Cancelation Data Analysis Project - Riya singh

# %%
import sys
# !python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the data set

# %%
df = pd.read_csv('C:/Users/hp/Downloads/hotel_dataset_10000_rows.csv')

# %% [markdown]
# Exploratory Data analysis and data cleaning

# %%
df.head(10)
# Out:
#           Hotel  Is_Canceled  Lead_Time  Arrival_Date_Year Arrival_Date_Month  \
# 0  Resort Hotel            0         36               2025               July
# 1    City Hotel            1         21               2025                May
# 2    City Hotel            1        101               2025               June
# 3  Resort Hotel            0         76               2025            January
# 4    City Hotel            0         24               2025          September
# 5    City Hotel            1        100               2025                May
# 6    City Hotel            0         40               2025             August
# 7    City Hotel            1         17               2025            January
# 8  Resort Hotel            0         71               2025            January
# 9  Resort Hotel            1        125               2025               June
#
#    Arrival_Date_Week_Number  Arrival_Date_Day_of_Month  \
# ...

# %%
df.tail()
# Out:
#              Hotel  Is_Canceled  Lead_Time  Arrival_Date_Year  \
# 9995  Resort Hotel            0         20               2025
# 9996    City Hotel            1        132               2025
# 9997  Resort Hotel            0         98               2025
# 9998    City Hotel            1         70               2025
# 9999  Resort Hotel            1         22               2025
#
#      Arrival_Date_Month  Arrival_Date_Week_Number  Arrival_Date_Day_of_Month  \
# 9995           February                         7                         11
# 9996             August                        33                         14
# 9997               July                        30                         27
# 9998          September                        39                         27
# 9999            October                        43                         23
#
#       Stays_in_Weekend_Nights  Stays_in_Week_Nights  Adults  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Hotel', 'Is_Canceled', 'Lead_Time', 'Arrival_Date_Year',
#        'Arrival_Date_Month', 'Arrival_Date_Week_Number',
#        'Arrival_Date_Day_of_Month', 'Stays_in_Weekend_Nights',
#        'Stays_in_Week_Nights', 'Adults', 'Children', 'Babies', 'Meal',
#        'Country', 'Market_Segment', 'Distribution_Channel',
#        'Is_Repeated_Guest', 'Previous_Cancellations',
#        'Previous_Bookings_Not_Canceled', 'Reserved_Room_Type',
#        'Assigned_Room_Type', 'Booking_Changes', 'Deposit_Type', 'Agent',
#        'Company', 'Days_in_Waiting_List', 'Customer_Type', 'ADR',
#        'Required_Car_Parking_Spaces', 'Total_of_Special_Requests',
#        'Reservation_Status', 'Reservation_Status_Date'],
#       dtype='str')

# %%
df.shape
# Out:
# (10000, 32)

# %%
df.columns
# Out:
# Index(['Hotel', 'Is_Canceled', 'Lead_Time', 'Arrival_Date_Year',
#        'Arrival_Date_Month', 'Arrival_Date_Week_Number',
#        'Arrival_Date_Day_of_Month', 'Stays_in_Weekend_Nights',
#        'Stays_in_Week_Nights', 'Adults', 'Children', 'Babies', 'Meal',
#        'Country', 'Market_Segment', 'Distribution_Channel',
#        'Is_Repeated_Guest', 'Previous_Cancellations',
#        'Previous_Bookings_Not_Canceled', 'Reserved_Room_Type',
#        'Assigned_Room_Type', 'Booking_Changes', 'Deposit_Type', 'Agent',
#        'Company', 'Days_in_Waiting_List', 'Customer_Type', 'ADR',
#        'Required_Car_Parking_Spaces', 'Total_of_Special_Requests',
#        'Reservation_Status', 'Reservation_Status_Date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Hotel                           10000 non-null  str
#  1   Is_Canceled                     10000 non-null  int64
#  2   Lead_Time                       10000 non-null  int64
#  3   Arrival_Date_Year               10000 non-null  int64
#  4   Arrival_Date_Month              10000 non-null  str
#  5   Arrival_Date_Week_Number        10000 non-null  int64
#  6   Arrival_Date_Day_of_Month       10000 non-null  int64
#  7   Stays_in_Weekend_Nights         10000 non-null  int64
#  8   Stays_in_Week_Nights            10000 non-null  int64
#  9   Adults                          10000 non-null  int64
#  10  Children                        10000 non-null  int64
#  11  Babies                          10000 non-null  int64
# ...

# %%
# Reservation_status_date (30) is an object, so converting it into date_time type
df['Reservation_Status_Date'] = pd.to_datetime(df['Reservation_Status_Date'], format= 'mixed')

# %%
#To check summary statistics of objects (categorical data types) in the dataset
df.describe(include = 'object')
# Out:
#              Hotel Arrival_Date_Month   Meal Country Market_Segment  \
# count        10000              10000  10000   10000          10000
# unique           2                 12      3       5              4
# top     City Hotel            January     HB     CAN      Online TA
# freq          5047                893   3407    2059           2532
#
#        Distribution_Channel Reserved_Room_Type Assigned_Room_Type  \
# count                 10000              10000              10000
# unique                    2                  5                  5
# top                  Direct                  B                  B
# freq                   5091               2056               2022
#
#        Deposit_Type Customer_Type Reservation_Status
# count         10000         10000              10000
# unique            3             3                  2
# top      Refundable     Transient           Canceled
# freq           3376          3350               5033

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('*-'*40)
# Out:
# Hotel
# <StringArray>
# ['Resort Hotel', 'City Hotel']
# Length: 2, dtype: str
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# Arrival_Date_Month
# <StringArray>
# [     'July',       'May',      'June',   'January', 'September',    'August',
#      'April',   'October',  'November',  'February',     'March',  'December']
# Length: 12, dtype: str
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# Meal
# <StringArray>
# ['HB', 'FB', 'BB']
# Length: 3, dtype: str
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# Country
# <StringArray>
# ['CAN', 'AUS', 'IND', 'USA', 'UK']
# Length: 5, dtype: str
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# Market_Segment
# <StringArray>
# ['Online TA', 'Corporate', 'Offline TA/TO', 'Direct']
# Length: 4, dtype: str
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# ...

# %%
df.isnull().sum()
# Out:
# Hotel                                 0
# Is_Canceled                           0
# Lead_Time                             0
# Arrival_Date_Year                     0
# Arrival_Date_Month                    0
# Arrival_Date_Week_Number              0
# Arrival_Date_Day_of_Month             0
# Stays_in_Weekend_Nights               0
# Stays_in_Week_Nights                  0
# Adults                                0
# Children                              0
# Babies                                0
# Meal                                  0
# Country                               0
# Market_Segment                        0
# Distribution_Channel                  0
# Is_Repeated_Guest                     0
# Previous_Cancellations                0
# Previous_Bookings_Not_Canceled        0
# Reserved_Room_Type                    0
# Assigned_Room_Type                    0
# Booking_Changes                       0
# Deposit_Type                          0
# ...

# %%
#Sales company column has much null values We Need Agent So we are dropping Them wont make a significant change to the analysis so Well so we will drop null rows.
df.drop(['Company','Agent'],axis = 1, inplace=True)
df.dropna(inplace = True)

# %%
#Checking missing values
df.isnull().sum()
# Out:
# Hotel                             0
# Is_Canceled                       0
# Lead_Time                         0
# Arrival_Date_Year                 0
# Arrival_Date_Month                0
# Arrival_Date_Week_Number          0
# Arrival_Date_Day_of_Month         0
# Stays_in_Weekend_Nights           0
# Stays_in_Week_Nights              0
# Adults                            0
# Children                          0
# Babies                            0
# Meal                              0
# Country                           0
# Market_Segment                    0
# Distribution_Channel              0
# Is_Repeated_Guest                 0
# Previous_Cancellations            0
# Previous_Bookings_Not_Canceled    0
# Reserved_Room_Type                0
# Assigned_Room_Type                0
# Booking_Changes                   0
# Deposit_Type                      0
# Days_in_Waiting_List              0
# Customer_Type                     0
# ADR                               0
# ...

# %%
#summary statistics of numerical column to check outliers
df.describe()
# Out:
#         Is_Canceled     Lead_Time  Arrival_Date_Year  \
# count  10000.000000  10000.000000            10000.0
# mean       0.506200     99.990300             2025.0
# min        0.000000      1.000000             2025.0
# 25%        0.000000     50.000000             2025.0
# 50%        1.000000    100.000000             2025.0
# 75%        1.000000    150.000000             2025.0
# max        1.000000    200.000000             2025.0
# std        0.499987     57.617391                0.0
#
#        Arrival_Date_Week_Number  Arrival_Date_Day_of_Month  \
# count              10000.000000               10000.000000
# mean                  26.383100                  15.617400
# min                    1.000000                   1.000000
# 25%                   13.000000                   8.000000
# 50%                   26.000000                  15.000000
# 75%                   40.000000                  23.000000
# max                   52.000000                  31.000000
# ...

# %%
df['ADR'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
#we have to remove the outlier that we just spotted  and can be seen in the above box plot
df=df[df['ADR']<5000]

# %%
df.describe()
# Out:
#         Is_Canceled     Lead_Time  Arrival_Date_Year  \
# count  10000.000000  10000.000000            10000.0
# mean       0.506200     99.990300             2025.0
# min        0.000000      1.000000             2025.0
# 25%        0.000000     50.000000             2025.0
# 50%        1.000000    100.000000             2025.0
# 75%        1.000000    150.000000             2025.0
# max        1.000000    200.000000             2025.0
# std        0.499987     57.617391                0.0
#
#        Arrival_Date_Week_Number  Arrival_Date_Day_of_Month  \
# count              10000.000000               10000.000000
# mean                  26.383100                  15.617400
# min                    1.000000                   1.000000
# 25%                   13.000000                   8.000000
# 50%                   26.000000                  15.000000
# 75%                   40.000000                  23.000000
# max                   52.000000                  31.000000
# ...

# %% [markdown]
# Data Analysis and Visualizations

# %%
# we want to see canceled and non canceled datareservations data  first.
cancelled_perc = df['Is_Canceled'].value_counts(normalize = True)
cancelled_perc
# Out:
# Is_Canceled
# 1    0.5062
# 0    0.4938
# Name: proportion, dtype: float64

# %%
print(cancelled_perc)

plt.figure(figsize = (5,4))
plt.title('Reservation Status Count')
plt.bar (['Not Canceled', 'Canceled'], df['Is_Canceled'].value_counts(),edgecolor='k', width = 0.7)
plt.show()
# Out:
# Is_Canceled
# 1    0.5062
# 0    0.4938
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (8,4))
axl = sns.countplot(x = 'Hotel', hue = 'Is_Canceled', data = df, palette = 'Blues')
legend_labels,_=axl.get_legend_handles_labels()
plt.title('Reservation Status in Different Hotels', size = 20)
plt.xlabel('Hotel')
plt.ylabel('Number of Reservations')
plt.legend(['Not Canceled','Canceled'])
plt.show()
